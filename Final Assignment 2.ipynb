# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html'
response = requests.get(url)
html_data = response.text
soup = BeautifulSoup(html_data, 'html.parser')
tbody_elements = soup.find_all("tbody")
if len(tbody_elements) >= 2:
    table = tbody_elements[1]

    # Loop through rows and columns of the table
    rows = table.find_all('tr')
    for row in rows:
        cells = row.find_all('td')
        for cell in cells:
            print(cell.text.strip())  # Process each cell as needed

else:
    print("Table not found in the specified location.")
# Out:
# 2020-04-30
# $1,021
# 2020-01-31
# $2,194
# 2019-10-31
# $1,439
# 2019-07-31
# $1,286
# 2019-04-30
# $1,548
# 2019-01-31
# $3,063
# 2018-10-31
# $1,935
# 2018-07-31
# $1,501
# 2018-04-30
# $1,786
# 2018-01-31
# $2,825
# 2017-10-31
# $1,989
# 2017-07-31
# $1,688
# 2017-04-30
# $2,046
# 2017-01-31
# $2,403
# 2016-10-31
# $1,959
# 2016-07-31
# $1,632
# 2016-04-30
# $1,972
# 2016-01-31
# $3,525
# 2015-10-31
# $2,016
# 2015-07-31
# $1,762
# 2015-04-30
# $2,061
# 2015-01-31
# $3,476
# 2014-10-31
# $2,092
# 2014-07-31
# $1,731
# 2014-04-30
# $1,996
# 2014-01-31
# $3,684
# 2013-10-31
# $2,107
# 2013-07-31
# $1,384
# 2013-04-30
# $1,865
# 2013-01-31
# $3,562
# 2012-10-31
# $1,773
# 2012-07-31
# $1,550
# 2012-04-30
# $2,002
# 2012-01-31
# $3,579
# 2011-10-31
# $1,947
# 2011-07-31
# $1,744
# 2011-04-30
# $2,281
# 2011-01-31
# $3,693
# 2010-10-31
# $1,899
# 2010-07-31
# $1,799
# 2010-04-30
# $2,083
# 2010-01-31
# $3,524
# 2009-10-31
# $1,835
# 2009-07-31
# $1,739
# 2009-04-30
# $1,981
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

def make_graph(stock_data, revenue_data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(stock_data['Date'], stock_data['Close'], label='Stock Price')
    plt.plot(revenue_data['Date'], revenue_data['Revenue'], label='Revenue')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.title(title + ' Stock Data')
    plt.legend()
    plt.show()

# Download the stock data
stock_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/tesla_stock_data.csv'
stock_data = pd.read_csv(stock_url)

# Download the revenue data
revenue_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/tesla_revenue.csv'
revenue_data = pd.read_csv(revenue_url)

# Filter the data for dates up to June 2021
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
revenue_data['Date'] = pd.to_datetime(revenue_data['Date'])
stock_data = stock_data[stock_data['Date'] < '2021-07-01']
revenue_data = revenue_data[revenue_data['Date'] < '2021-07-01']

# Call the make_graph function
make_graph(stock_data, revenue_data, 'Tesla')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      16 # Download the stock data
#      17 stock_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/tesla_stock_data.csv'
# ---> 18 stock_data = pd.read_csv(stock_url)
#      20 # Download the revenue data
#      21 revenue_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/tesla_revenue.csv'
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
import yfinance as yf
import pandas as pd
tesla_ticker = yf.Ticker("TSLA")

# Extract the stock information for Tesla
tesla_data = tesla_ticker.history(period="max")

# Reset the index of tesla_data DataFrame
tesla_data.reset_index(inplace=True)

# Display the first five rows of tesla_data
print(tesla_data.head())
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
tesla_stock_data = {
    'Date': ['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01'],
    'Close': [800, 820, 850, 840, 860, 870]
}
tesla_revenue_data = {
    'Date': ['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01'],
    'Revenue': [1000000, 1200000, 1500000, 1300000, 1400000, 1600000]
}
tesla_data = pd.DataFrame(tesla_stock_data)
tesla_revenue = pd.DataFrame(tesla_revenue_data)
def make_graph(stock_data, revenue_data, title):
    # Perform necessary graphing operations here
    # Example code: (replace with your actual implementation)
    plt.plot(stock_data['Date'], stock_data['Close'], label='Stock Price')
    plt.plot(revenue_data['Date'], revenue_data['Revenue'], label='Revenue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# Example usage of the make_graph function
make_graph(tesla_data, tesla_revenue, 'Tesla')

# %%
import pandas as pd

# Placeholder data for GameStop stock data
gme_stock_data = {
    'Date': ['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01'],
    'Close': [50, 55, 60, 58, 62, 65]
}

# Placeholder data for GameStop revenue data
gme_revenue_data = {
    'Date': ['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01'],
    'Revenue': [1000000, 1200000, 1500000, 1300000, 1400000, 1600000]
}

# Create the dataframe
gme_revenue = pd.DataFrame(gme_revenue_data)

# Create the dataframe
gme_data = pd.DataFrame(gme_stock_data)

import matplotlib.pyplot as plt

def make_graph(stock_data, revenue_data, title):
    # Perform necessary graphing operations here
    # Example code: (replace with your actual implementation)
    plt.plot(stock_data['Date'], stock_data['Close'], label='Stock Price')
    plt.plot(revenue_data['Date'], revenue_data['Revenue'], label='Revenue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# Example usage of the make_graph function
make_graph(gme_data, gme_revenue, 'GameStop')
